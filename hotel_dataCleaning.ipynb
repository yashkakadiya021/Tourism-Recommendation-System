# %%
import pandas as pd

# %%
df=pd.read_csv("all_guj_hotels.csv")
df
# Out:
#                                 hotel name  rating rating text  \
# 0     The Fern Sattva Resort - Polo Forest     4.3   Excellent
# 1                      Pride Resort Ambaji     3.8   Very Good
# 2                          Royal Inn Hotel     3.9   Very Good
# 3                    hotel leela residency     3.9   Very Good
# 4                        HOTEL KARDHAR INN     4.2   Very Good
# ...                                    ...     ...         ...
# 2360                         Hotel Vardhan     3.1        Good
# 2361                       Hotel The Seven     3.0        Good
# 2362                           Yatri Niwas     3.8   Very Good
# 2363                           Hotel Suraj     NaN         NaN
# 2364                  Ras Resorts by Treat     3.9   Very Good
#
#                       place                    near by place discount price  \
# 0                   Abhapur  96.8 km from Ambaji city centre        ₹ 3,896
# ...

# %%
df['rating'].mean()
# Out:
# np.float64(3.5459047619047617)

# %%
df['rating'] = df['rating'].fillna(3.5)
df
# Out:
#                                 hotel name  rating rating text  \
# 0     The Fern Sattva Resort - Polo Forest     4.3   Excellent
# 1                      Pride Resort Ambaji     3.8   Very Good
# 2                          Royal Inn Hotel     3.9   Very Good
# 3                    hotel leela residency     3.9   Very Good
# 4                        HOTEL KARDHAR INN     4.2   Very Good
# ...                                    ...     ...         ...
# 2360                         Hotel Vardhan     3.1        Good
# 2361                       Hotel The Seven     3.0        Good
# 2362                           Yatri Niwas     3.8   Very Good
# 2363                           Hotel Suraj     3.5         NaN
# 2364                  Ras Resorts by Treat     3.9   Very Good
#
#                       place                    near by place discount price  \
# 0                   Abhapur  96.8 km from Ambaji city centre        ₹ 3,896
# ...

# %%
df['facilities'].isnull().sum()
# Out:
# np.int64(545)

# %%
df['facilities']=df['facilities'].fillna('24-hour Room service')
df
# Out:
#                                 hotel name  rating rating text  \
# 0     The Fern Sattva Resort - Polo Forest     4.3   Excellent
# 1                      Pride Resort Ambaji     3.8   Very Good
# 2                          Royal Inn Hotel     3.9   Very Good
# 3                    hotel leela residency     3.9   Very Good
# 4                        HOTEL KARDHAR INN     4.2   Very Good
# ...                                    ...     ...         ...
# 2360                         Hotel Vardhan     3.1        Good
# 2361                       Hotel The Seven     3.0        Good
# 2362                           Yatri Niwas     3.8   Very Good
# 2363                           Hotel Suraj     3.5         NaN
# 2364                  Ras Resorts by Treat     3.9   Very Good
#
#                       place                    near by place discount price  \
# 0                   Abhapur  96.8 km from Ambaji city centre        ₹ 3,896
# ...

# %%
df['facilities'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['rating text'].isnull().sum()
# Out:
# np.int64(265)

# %%
df['rating text']=df['rating text'].fillna('Very Good')
df
# Out:
#                                 hotel name  rating rating text  \
# 0     The Fern Sattva Resort - Polo Forest     4.3   Excellent
# 1                      Pride Resort Ambaji     3.8   Very Good
# 2                          Royal Inn Hotel     3.9   Very Good
# 3                    hotel leela residency     3.9   Very Good
# 4                        HOTEL KARDHAR INN     4.2   Very Good
# ...                                    ...     ...         ...
# 2360                         Hotel Vardhan     3.1        Good
# 2361                       Hotel The Seven     3.0        Good
# 2362                           Yatri Niwas     3.8   Very Good
# 2363                           Hotel Suraj     3.5   Very Good
# 2364                  Ras Resorts by Treat     3.9   Very Good
#
#                       place                    near by place discount price  \
# 0                   Abhapur  96.8 km from Ambaji city centre        ₹ 3,896
# ...

# %%
df['rating text'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("hotel_clen.csv", index=False)
